# %% [markdown]
# <a href="https://colab.research.google.com/github/doaa-teq/Antifungal-rug-discovery-using-AI-and-bioinformatics/blob/main/python/CDD_ML_Part_1_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Computational Drug Discovery of Antifungal drugs**
#
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Aspergillus fumigatus **

# %%
# Target search for Aspergillus fumigatus
target = new_client.target
target_query = target.search('Aspergillus fumigatus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#    cross_references                   organism  \
# 0                []      Aspergillus fumigatus
# 1                []                Aspergillus
# 2                []      Aspergillus fumigatus
# 3                []      Aspergillus fumigatus
# 4                []       Aspergillus nidulans
# 5                []         Aspergillus flavus
# 6                []          Aspergillus niger
# 7                []            Aspergillus sp.
# 8                []         Aspergillus oryzae
# 9                []         Aspergillus wentii
# 10               []      Aspergillus ochraceus
# 11               []  Aspergillus pseudoglaucus
# 12               []        Aspergillus terreus
# 13               []    Aspergillus parasiticus
# 14               []          Aspergillus ruber
# 15               []       Aspergillus inflatus
# 16               []     Aspergillus versicolor
# 17               []         Aspergillus ficuum
# 18               []        Aspergillus awamori
# ...

# %% [markdown]
# \### **Select and retrieve bioactivity data for *Glycoside_hydrolase_SF* (second entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL4638'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(type="IC50")#lower IC50 value more potent

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None     10963319                  []
# 1        None             None     10963320                  []
# 2        None             None     10963321                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL2060191  Inhibition of Aspergillus fumigatus ChitinaseB...
# 1   CHEMBL2060191  Inhibition of Aspergillus fumigatus ChitinaseB...
# 2   CHEMBL2060191  Inhibition of Aspergillus fumigatus ChitinaseB...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
#
#          target_organism target_pref_name target_tax_id text_value  toid  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 69
# -rw------- 1 root root 70010 Apr 29 17:10 bioactivity_data.csv

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.value.notna()]
df2 #make sure no missing data
# Out:
#                                          action_type activity_comment  \
# 0                                               None             None
# 1                                               None             None
# 2                                               None             None
# 3                                               None             None
# 4  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 5  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#    activity_id activity_properties assay_chembl_id  \
# 0     10963319                  []   CHEMBL2060191
# 1     10963320                  []   CHEMBL2060191
# 2     10963321                  []   CHEMBL2060191
# 3     10963322                  []   CHEMBL2060191
# 4     22849281                  []   CHEMBL4722994
# 5     22849282                  []   CHEMBL4722994
#
#                                    assay_description assay_type  \
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = [] #classivy data accourding to value of IC50
for i in df2.value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# # **Final Results**

# %%
selection = ['assay_chembl_id', 'canonical_smiles', 'value']
df3 = df2[selection]
df3
# Out:
#   assay_chembl_id                                   canonical_smiles  \
# 0   CHEMBL2060191  Cn1cnc2c1c(=O)n(CCn1c(=O)c3c(ncn3C)n(C)c1=O)c(...
# 1   CHEMBL2060191  Cn1cnc2c1c(=O)n(CCCn1c(=O)c3c(ncn3C)n(C)c1=O)c...
# 2   CHEMBL2060191  Cn1cnc2c1c(=O)n(CCCCn1c(=O)c3c(ncn3C)n(C)c1=O)...
# 3   CHEMBL2060191  Cn1cnc2c1c(=O)n(CCCCCn1c(=O)c3c(ncn3C)n(C)c1=O...
# 4   CHEMBL4722994                                    CNC(=N)NC(=O)NC
# 5   CHEMBL4722994  CNC(=O)NC(=N)NCCC[C@H]1CN(C)[C@@H](Cc2ccccc2)C...
#
#                   value
# 0                   4.8
# 1                   0.2
# 2                   9.0
# 3                   5.7
# 4                 500.0
# 5  0.027000000000000003

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)#use Bioactivity class to classify ids accourding to values
# Out:
#   assay_chembl_id                                   canonical_smiles  \
# 0   CHEMBL2060191  Cn1cnc2c1c(=O)n(CCn1c(=O)c3c(ncn3C)n(C)c1=O)c(...
# 1   CHEMBL2060191  Cn1cnc2c1c(=O)n(CCCn1c(=O)c3c(ncn3C)n(C)c1=O)c...
# 2   CHEMBL2060191  Cn1cnc2c1c(=O)n(CCCCn1c(=O)c3c(ncn3C)n(C)c1=O)...
# 3   CHEMBL2060191  Cn1cnc2c1c(=O)n(CCCCCn1c(=O)c3c(ncn3C)n(C)c1=O...
# 4   CHEMBL4722994                                    CNC(=N)NC(=O)NC
# 5   CHEMBL4722994  CNC(=O)NC(=N)NCCC[C@H]1CN(C)[C@@H](Cc2ccccc2)C...
#
#                   value       0
# 0                   4.8  active
# 1                   0.2  active
# 2                   9.0  active
# 3                   5.7  active
# 4                 500.0  active
# 5  0.027000000000000003  active

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 92
# -rw-r--r-- 1 root root 70010 Apr 29 17:07 bioactivity_data.csv
# -rw-r--r-- 1 root root  9326 Apr 29 17:24 bioactivity_preprocessed_data.csv
# drwx------ 4 root root  4096 Apr 29 17:08 gdrive
# drwxr-xr-x 1 root root  4096 Apr  3 16:24 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_data.csv  bioactivity_preprocessed_data.csv

# %% [markdown]
# ---
